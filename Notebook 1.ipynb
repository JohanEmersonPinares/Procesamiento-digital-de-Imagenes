# %% [markdown]
# # Pregunta 1

# %% [markdown]
# Realizar 3 banderas de diferentes países en 3 dimensiones (imagen a colores), usando los conocimientos aprendidos.

# %% [markdown]
# Importacion de librerias Numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bandera de Suecia

# %%
Bandera_suecia=np.zeros((5,8,3))

primero=np.array([[70, 130, 180],[70, 130, 180],[255, 215, 0],[70, 130, 180],[70, 130, 180],
[70, 130, 180],[70, 130, 180],[70, 130, 180]])
segundo=np.array([[255, 215, 0],[255, 215, 0],[255, 215, 0],[255, 215, 0],[255, 215, 0],
[255, 215, 0],[255, 215, 0],[255, 215, 0]])
Bandera_suecia[:][:][0] =primero
Bandera_suecia[:][:][1] =primero
Bandera_suecia[:][:][2] =segundo
Bandera_suecia[:][:][3] =primero
Bandera_suecia[:][:][4] =primero
print(Bandera_suecia)
plt.imshow(Bandera_suecia)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [255. 215.   0.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]]
#
#  [[ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [255. 215.   0.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]]
#
#  [[255. 215.   0.]
#   [255. 215.   0.]
#   [255. 215.   0.]
#   [255. 215.   0.]
#   [255. 215.   0.]
#   [255. 215.   0.]
#   [255. 215.   0.]
#   [255. 215.   0.]]
#
#  [[ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [255. 215.   0.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]]
#
#  [[ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [255. 215.   0.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]
#   [ 70. 130. 180.]]]

# %%
Bandera_suecia_uint8=Bandera_suecia.astype(np.uint8)
plt.imshow(Bandera_suecia_uint8)

# %% [markdown]
# ## Bandera de Grecia

# %%
Bandera_grecia=np.zeros((9,13,3))

primero=np.array([[25, 25, 112],[25, 25, 112],[255, 255, 255],[25, 25, 112],[25, 25, 112],
[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112]])
segundo=np.array([[25, 25, 112],[25, 25, 112],[255, 255, 255],[25, 25, 112],[25, 25, 112],
[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255]])
tercero=np.array([[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],
[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112]])
cuarto=np.array([[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],
[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255]])
quinto=np.array([[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],
[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112],[25, 25, 112]])
Bandera_grecia[:][:][0] =primero
Bandera_grecia[:][:][1] =segundo
Bandera_grecia[:][:][2] =tercero
Bandera_grecia[:][:][3] =segundo
Bandera_grecia[:][:][4] =primero
Bandera_grecia[:][:][5] =cuarto
Bandera_grecia[:][:][6] =quinto
Bandera_grecia[:][:][7] =cuarto
Bandera_grecia[:][:][8] =quinto
print(Bandera_grecia)
plt.imshow(Bandera_grecia)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [255. 255. 255.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]]
#
#  [[ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [255. 255. 255.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]
#   [ 25.  25. 112.]]
#
#  [[ 25.  25. 112.]
#   [ 25.  25. 112.]
# ...

# %%
Bandera_grecia_uint8=Bandera_grecia.astype(np.uint8)
plt.imshow(Bandera_grecia_uint8)

# %% [markdown]
# ## Bandera de Georgia

# %%
Bandera_georgia=np.zeros((12,16,3))

primero=np.array([[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255],
[255, 255, 255],[255, 255, 255],[255, 0, 0],[255, 0, 0],[255, 255, 255],[255, 255, 255],[255, 255, 255],
[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 255, 255]])
segundo=np.array([[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 0, 0],[255, 255, 255],
[255, 255, 255],[255, 255, 255],[255, 0, 0],[255, 0, 0],[255, 255, 255],[255, 255, 255],[255, 255, 255],[255, 0, 0],
[255, 255, 255],[255, 255, 255],[255, 255, 255]])
tercero=np.array([[255, 255, 255],[255, 255, 255],[255, 0, 0],[255, 0, 0],[255, 0, 0],
[255, 255, 255],[255, 255, 255],[255, 0, 0],[255, 0, 0],[255, 255, 255],[255, 255, 255],[255, 0, 0],[255, 0, 0],
[255, 0, 0],[255, 255, 255],[255, 255, 255]])
cuarto=np.array([[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0],
[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0],
[255, 0, 0],[255, 0, 0],[255, 0, 0],[255, 0, 0]])
Bandera_georgia[:][:][0] =primero
Bandera_georgia[:][:][1] =segundo
Bandera_georgia[:][:][2] =tercero
Bandera_georgia[:][:][3] =segundo
Bandera_georgia[:][:][4] =primero
Bandera_georgia[:][:][5] =cuarto
Bandera_georgia[:][:][6] =cuarto
Bandera_georgia[:][:][7] =primero
Bandera_georgia[:][:][8] =segundo
Bandera_georgia[:][:][9] =tercero
Bandera_georgia[:][:][10] =segundo
Bandera_georgia[:][:][11] =primero

print(Bandera_georgia)
plt.imshow(Bandera_georgia)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255.   0.   0.]
#   [255.   0.   0.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255.   0.   0.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255.   0.   0.]
#   [255.   0.   0.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255.   0.   0.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255. 255. 255.]]
#
#  [[255. 255. 255.]
#   [255. 255. 255.]
#   [255.   0.   0.]
#   [255.   0.   0.]
#   [255.   0.   0.]
#   [255. 255. 255.]
#   [255. 255. 255.]
#   [255.   0.   0.]
#   [255.   0.   0.]
#   [255. 255. 255.]
# ...

# %% [markdown]
# # Pregunta 2

# %% [markdown]
# Crear UNA función para transformar una imagen en RGB a grises y luego al formato binario, lee los siguientes pasos:

# %% [markdown]
# Si ingresas una imagen en RGB a la función debe regresar la conversión a grises y luego el binario.
# Si ingresas una imagen en grises a la función debe retornar tan solo la imagen binaria.
# Crea dos ejemplos probando cada caso, una imagen RGB y luego una en grises.

# %%
#!apt update && apt install -y ffmpeg libsm6 libxext6

# %%
# !apt update && apt install -y ffmpeg libsm6 libxext6
# Out:
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 http://deb.debian.org/debian-security buster/updates InRelease
# Hit:3 http://deb.debian.org/debian buster-updates InRelease
#
#
#
# 21 packages can be upgraded. Run 'apt list --upgradable' to see them.
#
#
#
# ffmpeg is already the newest version (7:4.1.9-0+deb10u1).
# libsm6 is already the newest version (2:1.2.3-1).
# libxext6 is already the newest version (2:1.3.3-1+b2).
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.

# %%
import cv2

# %% [markdown]
# Imagen RGB a Gris y luego a Binario

# %%
imagen_pg1=cv2.imread("/work/pc1.jpeg")
imagen_rgb = cv2.cvtColor(imagen_pg1, cv2.COLOR_BGR2RGB)
plt.imshow(imagen_rgb)

# %%
def convertirrgbgris(imagen,umbral):
    d=len(imagen.shape)
    if d==3:
        R=imagen[:,:,0]
        G=imagen[:,:,1]
        B=imagen[:,:,2]
        imagen_gris=0.299*R+0.587*G+0.114*B
        imagen_binaria=imagen_gris > umbral 
        return (imagen_gris.astype(np.uint8),imagen_binaria.astype(np.ubyte))      
    else:
        imagen_binaria = imagen > umbral 
        return imagen_binaria.astype(np.ubyte)

# %%
(imggris,imggbin)= convertirrgbgris(imagen_rgb,126)

plt.gray()

f, (ax1, ax2) = plt.subplots(1, 2)
plt.xticks([])
plt.yticks([])
ax1.imshow(imggris)
ax2.imshow(imggbin)
ax1.set_title("Gris")
ax2.set_title("Binaria")
plt.show()

# %% [markdown]
# Imagen gris a binario

# %%
imagen_pg2=cv2.imread("/work/22.jpeg")
imagen_gris2 = cv2.cvtColor(imagen_pg2, cv2.COLOR_BGR2GRAY)
plt.imshow(imagen_gris2)
plt.gray()

# %%
(img2)= convertirrgbgris(imagen_gris2,126)
plt.imshow(img2)

# %%
umb=128
img_binary=imggris > umb
plt.imshow(img_binary)

# %% [markdown]
# # Pregunta 3

# %% [markdown]
# De la imagen anterior de la foto de una persona, realiza un corte del rostro de la foto y luego agregale un marco.

# %%
#Convertir a gris
imagen = cv2.imread("/work/pc1.jpeg")
imagen_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
plt.imshow(imagen_gris)

# %%
print(len(imagen_gris.shape)) # es gris
print(len(imagen.shape)) # es color
# Out:
# 2
# 3

# %%
inicio_x = 100
inicio_y = 100
alto = 1000
ancho = 1200
imagen_cortada = imagen_gris[inicio_y:inicio_y+alto,inicio_x:inicio_x+ancho]
plt.imshow(imagen_cortada)

# %%
from Funciones.marcos import agregar_marcos
marcos = agregar_marcos(imagen_cortada, 30, 30)
plt.imshow(marcos)

# %% [markdown]
# # Pregunta 4

# %% [markdown]
# Se tiene dos fotos, la primera es una imagen de machu picchu incompleta, y la otra es una imagen de machu picchu en la mitad, ambas imágenes podrían formar una sola, coloca la mitad faltante en la parte negra y muestra tus resultados.

# %%
imagen = cv2.imread("/work/imagenes/pc1/mc.jpg")
imagen_gris1 = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
plt.imshow(imagen_gris1)
plt.gray()

# %%
imagen = cv2.imread("/work/imagenes/pc1/mccortado.jpg")
imagen_gris2 = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
plt.imshow(imagen_gris2)
plt.gray()

# %%
inicio_x = 639
inicio_y = 0
alto = 720
ancho = 641
imagen_gris1[inicio_y:inicio_y+alto,inicio_x:inicio_x+ancho]=imagen_gris2
plt.imshow(imagen_gris1)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bbcab511-fb43-457a-9f8f-a748e4325446' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
